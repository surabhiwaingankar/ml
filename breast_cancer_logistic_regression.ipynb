# %% [markdown]
# <a href="https://colab.research.google.com/github/surabhiwaingankar/ml_az/blob/main/breast_cancer_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('breast_cancer.csv')

# %%
df.head(5)
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample code number           683 non-null    int64
#  1   Clump Thickness              683 non-null    int64
#  2   Uniformity of Cell Size      683 non-null    int64
#  3   Uniformity of Cell Shape     683 non-null    int64
#  4   Marginal Adhesion            683 non-null    int64
#  5   Single Epithelial Cell Size  683 non-null    int64
#  6   Bare Nuclei                  683 non-null    int64
#  7   Bland Chromatin              683 non-null    int64
#  8   Normal Nucleoli              683 non-null    int64
#  9   Mitoses                      683 non-null    int64
#  10  Class                        683 non-null    int64
# dtypes: int64(11)
# memory usage: 58.8 KB

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 678                3                        1                         1
# 679                2                        1                         1
# 680                5                       10                        10
# 681                4                        8                         6
# 682                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %%
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 678    2
# 679    2
# 680    4
# 681    4
# 682    4
# Name: Class, Length: 683, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 312               10                        1                         1
# 202                1                        1                         1
# 263                5                        1                         1
# 395                3                        1                         2
# 101                8                        2                         3
# ..               ...                      ...                       ...
# 9                  4                        2                         1
# 359                5                        1                         1
# 192                1                        1                         1
# 629                3                        1                         1
# 559               10                        9                         7
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %%
y_train
# Out:
# 312    4
# 202    2
# 263    2
# 395    2
# 101    4
#       ..
# 9      2
# 359    2
# 192    2
# 629    2
# 559    4
# Name: Class, Length: 546, dtype: int64

# %%
X_test
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 113                1                        1                         1
# 378                3                        1                         1
# 303                5                        5                         5
# 504                4                        7                         8
# 301                1                        1                         1
# ..               ...                      ...                       ...
# 21                10                        5                         5
# 454                1                        1                         2
# 506                4                        1                         1
# 500                4                       10                         4
# 77                 2                        1                         1
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %%
y_test
# Out:
# 113    2
# 378    2
# 303    4
# 504    4
# 301    2
#       ..
# 21     4
# 454    2
# 506    2
# 500    4
# 77     2
# Name: Class, Length: 137, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([2, 2, 4, 4, 2, 2, 2, 4, 2, 2, 4, 2, 4, 2, 2, 2, 4, 4, 4, 2, 2, 2,
#        4, 2, 4, 4, 2, 2, 2, 4, 2, 4, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 2,
#        2, 2, 2, 4, 2, 2, 4, 2, 4, 2, 2, 2, 4, 4, 2, 4, 2, 2, 2, 2, 2, 2,
#        2, 2, 4, 4, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2, 4, 2, 4, 2, 2, 4, 2, 4,
#        4, 2, 4, 2, 4, 4, 2, 4, 4, 4, 4, 2, 2, 2, 4, 4, 2, 2, 4, 2, 2, 2,
#        4, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 4, 2, 4, 2, 4, 2, 2,
#        4, 2, 2, 4, 2])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[84,  3],
#        [ 3, 47]])

# %% [markdown]
# Only 6 incorrect predictions!
